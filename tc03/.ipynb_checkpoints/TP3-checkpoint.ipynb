# %% [markdown]
# # Trabajo Computacional 3

# %%
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors
import numpy as np
from  collections  import defaultdict
from scipy import optimize
import os
from lectura import ldata
from math import log
import community
#import rpy2.robjects as robjects
#import jgraph
#from jgraph import *

# %%
# El directorio que vamos a usar en cada lectura de datos de ahora en mas
directorio = os.path.dirname(os.path.realpath("dolphins.txt"))

# %%
fnDOL = os.path.join(directorio,'dolphins.gml')
delfines = nx.read_gml(fnDOL)
generos=ldata('dolphinsGender.txt')

# %%
nx.draw(delfines, with_labels=True)
plt.show()

# %%
#delfines.edges

# %% [markdown]
# Encuentre la partición en clusters de esta red utilizando la metodología Louvain, infomap,fast_greedy y edge_betweenness. Visualice los resultados gráficamente.

# %%
# Clustering Louvian 
com_lou_delfines = community.best_partition(delfines)
com_lou_delfines
# Out:
# {'Beak': 2,
#  'Beescratch': 0,
#  'Bumper': 2,
#  'CCL': 4,
#  'Cross': 3,
#  'DN16': 0,
#  'DN21': 0,
#  'DN63': 0,
#  'Double': 4,
#  'Feather': 0,
#  'Fish': 2,
#  'Five': 3,
#  'Fork': 1,
#  'Gallatin': 0,
#  'Grin': 1,
#  'Haecksel': 3,
#  'Hook': 1,
#  'Jet': 0,
#  'Jonah': 3,
#  'Knit': 0,
#  'Kringel': 1,
#  'MN105': 3,
#  'MN23': 0,
#  'MN60': 3,
#  'MN83': 3,
#  'Mus': 0,
#  'Notch': 0,
#  'Number1': 0,
#  'Oscar': 2,
#  'PL': 2,
#  'Patchback': 3,
#  'Quasi': 0,
#  'Ripplefluke': 0,
#  'SMN5': 3,
#  'SN100': 4,
#  'SN4': 1,
#  'SN63': 1,
#  'SN89': 4,
#  'SN9': 1,
#  'SN90': 0,
#  'SN96': 2,
#  'Scabs': 1,
#  'Shmuddel': 1,
#  'Stripes': 1,
#  'TR120': 1,
#  'TR77': 2,
#  'TR82': 0,
#  'TR88': 1,
#  'TR99': 1,
#  'TSN103': 1,
#  'TSN83': 1,
#  'Thumper': 1,
#  'Topless': 3,
#  'Trigger': 3,
#  'Upbang': 0,
#  'Vau': 3,
#  'Wave': 0,
#  'Web': 0,
#  'Whitetip': 1,
#  'Zap': 4,
#  'Zig': 0,
#  'Zipfel': 1}

# %%
# Clustering por maximizacion 'greedy' de modularidad

com_greedy_delfines = nx.algorithms.community.greedy_modularity_communities(delfines, weight=None)
list(com_greedy_delfines)
# Out:
# [frozenset({'Beak',
#             'Bumper',
#             'Fish',
#             'Fork',
#             'Grin',
#             'Hook',
#             'Kringel',
#             'SN4',
#             'SN63',
#             'SN9',
#             'SN96',
#             'Scabs',
#             'Shmuddel',
#             'Stripes',
#             'TR120',
#             'TR77',
#             'TR88',
#             'TR99',
#             'TSN103',
#             'TSN83',
#             'Thumper',
#             'Whitetip',
#             'Zipfel'}),
#  frozenset({'Beescratch',
#             'DN16',
#             'DN21',
#             'DN63',
#             'Feather',
#             'Gallatin',
#             'Jet',
#             'Knit',
#             'MN23',
#             'Mus',
#             'Notch',
#             'Number1',
#             'Oscar',
#             'PL',
#             'Quasi',
#             'Ripplefluke',
#             'SN90',
#             'TR82',
#             'Upbang',
#             'Wave',
#             'Web',
#             'Zig'}),
#  frozenset({'CCL',
#             'Cross',
#             'Double',
#             'Five',
#             'Haecksel',
#             'Jonah',
#             'MN105',
#             'MN60',
#             'MN83',
#             'Patchback',
#             'SMN5',
#             'Topless',
#             'Trigger',
#             'Vau',
#             'Zap'}),
#  frozenset({'SN100', 'SN89'})]

# %%
# Clustering por betweenness

com_beet_delfines = nx.algorithms.community.centrality.girvan_newman(delfines)

# %%
# Clustering infomap jgraph
#import igraph 
from igraph import Graph
#dol = igraph.
#com_infomap_delfines = delfines.
# Out:
# ---------------------------------------------------------------------------
# DeprecationWarning                        Traceback (most recent call last)
# <ipython-input-2-b29c81872aae> in <module>()
#       1 # Clustering infomap jgraph
#       2 #import igraph
# ----> 3 from igraph import Graph
#       4 #dol = igraph.
#       5 #com_infomap_delfines = delfines.
#
# /home/yuditsabet/paquetes/PREFIX=/home/yuditsabet/paquetes/envs/py35/lib/python3.5/site-packages/igraph/__init__.py in <module>()
#       6 __license__ = "MIT"
#       7
# ----> 8 raise DeprecationWarning("To avoid name collision with the igraph project, "
#       9                          "this visualization library has been renamed to "
#      10                          "'jgraph'. Please upgrade when convenient.")
#
# DeprecationWarning: To avoid name collision with the igraph project, this visualization library has been renamed to 'jgraph'. Please upgrade when convenient.
